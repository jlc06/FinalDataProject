# %%
def teamScrape(year):
    # Dependencies
    from splinter import Browser
    from bs4 import BeautifulSoup as soup
    from webdriver_manager.chrome import ChromeDriverManager
    import pandas as pd
    from functools import reduce
    # Set up Splinter
    executable_path = {'executable_path': ChromeDriverManager().install()}
    browser = Browser('chrome', **executable_path, headless=True)
    # Visit the AdvancedStats to Scrape site
    url = f'https://www.pro-football-reference.com/years/{year}/#all_team_stats'
    browser.visit(url)
    # Parse the HTML
    html = browser.html
    html_soup = soup(html, 'html.parser')
    # Find the tables
    df1 = html_soup.find('table', {"id" : 'team_stats'})
    df2 = html_soup.find('table', {"id" : 'passing'})
    df3 = html_soup.find('table', {"id" : 'rushing'})
    # Create dataframes
    df1 = pd.read_html(str(df1),header=1)[0]
    df2 = pd.read_html(str(df2),header=0)[0]
    df3 = pd.read_html(str(df3),header=0)[0]
    # Quit Splinter
    browser.quit()
    # Merge dataframes
    data_frames = [df1, df2, df3]
    df = reduce(lambda  left,right: pd.merge(left,right,on=['Tm'],
                            how='outer'), data_frames)
    teams = ['Dallas Cowboys','Tampa Bay Buccaneers','Buffalo Bills','Kansas City Chiefs','Los Angeles Chargers',
             'New England Patriots','Cincinnati Bengals','Los Angeles Rams','Indianapolis Colts','Green Bay Packers',
             'Arizona Cardinals','Philadelphia Eagles','San Francisco 49ers','Minnesota Vikings','Tennessee Titans',
             'Seattle Seahawks','Baltimore Ravens','Las Vegas Raiders','New Orleans Saints','Cleveland Browns',
             'Pittsburgh Steelers','Miami Dolphins','Denver Broncos','Washington Football Team','Detroit Lions',
             'Atlanta Falcons','Chicago Bears','New York Jets','Carolina Panthers','Houston Texans','New York Giants',
             'Jacksonville Jaguars','San Diego Chargers','St. Louis Rams','Oakland Raiders','Washington Redskins',
             'Wasington Commanders']
    abbr = {'Dallas Cowboys':'DAL','Tampa Bay Buccaneers':'TAM','Buffalo Bills':'BUF','Kansas City Chiefs':'KAN',
            'Los Angeles Chargers':'LAC','New England Patriots':'NWE','Cincinnati Bengals':'CIN',
            'Los Angeles Rams':'LAR','Indianapolis Colts':'IND','Green Bay Packers':'GNB','Arizona Cardinals':'ARI',
            'Philadelphia Eagles':'PHI','San Francisco 49ers':'SFO','Minnesota Vikings':'MIN',
            'Tennessee Titans':'TEN','Seattle Seahawks':'SEA','Baltimore Ravens':'BAL','Las Vegas Raiders':'LVR',
            'New Orleans Saints':'NOR','Cleveland Browns':'CLE','Pittsburgh Steelers':'PIT','Miami Dolphins':'MIA',
            'Denver Broncos':'DEN','Washington Football Team':'WAS','Detroit Lions':'DET','Atlanta Falcons':'ATL',
            'Chicago Bears':'CHI','New York Jets':'NYJ','Carolina Panthers':'CAR','Houston Texans':'HOU',
            'New York Giants':'NYG','Jacksonville Jaguars':'JAX','San Diego Chargers':'SDG','St. Louis Rams':'STL',
            'Oakland Raiders':'OAK','Washington Redskins':'WAS','Wasington Commanders':'WAS'}
    # Clean dataframe including only rows with actual teams + add abbreviations
    df = df[df['Tm'].isin(teams)]
    df['Abbr'] = df.apply(lambda row: abbr[row.Tm], axis=1)
    # Drop unnecessary duplicate columns
    df.drop(columns=['Rk','Rk_x','Rk_y'],inplace=True)
    # Reorganize columns, dropping other unnecessary columns
    columns = ['Tm','Abbr','G_x','PF','Yds_x','Ply','Y/P','TO','FL','1stD','Cmp_x',
           'Att_x','Cmp%','Yds.1_x', 'TD_x', 'TD%','Int_x', 'Int%','NY/A_x', '1stD.1',   
           'Lng_x', 'Y/A_y', 'AY/A', 'Y/C', 'Y/G_x', 'Rate', 'Sk',
           'Yds.1_y', 'Sk%', 'ANY/A', '4QC', 'GWD', 'EXP_y',
           'Att.1','Yds.2', 'TD.1', 'Lng_y','Y/A_x','Y/G_y','1stD.2','Fmb','EXP',
           'Pen', 'Yds.3', '1stPy', 'Sc%','TO%', 'EXP_x']
    df = df[columns]
    # Drop duplicates
    df = df.loc[:,~df.columns.duplicated()]
    # Rename some of the columns
    cols = []
    for column in df.columns:
        if column == 'G_x':
            cols.append('G')
        elif column == 'Yds_x':
            cols.append('TotYds')
        elif column == 'Cmp_x':
            cols.append('Cmp')
        elif column == 'Att_x':
            cols.append('PasAtt')
        elif column == 'Yds.1_x':
            cols.append('PassYds')
        elif column == 'TD_x':
            cols.append('PassTD')
        elif column == 'Int_x':
            cols.append('Int')
        elif column == 'NY/A_x':
            cols.append('NY/A') 
        elif column == '1stD.1':
            cols.append('Pass1stD')
        elif column == 'Lng_x':
            cols.append('PassLng')
        elif column == 'Y/A_y':
            cols.append('Y/PassA')
        elif column == 'AY/A':
            cols.append('AY/PassA')
        elif column == 'Y/G_x':
            cols.append('PassY/G')
        elif column == 'Yds.1_y':
            cols.append('SackYds')
        elif column == 'ANY/A':
            cols.append('ANY/PassA')
        elif column == 'EXP_y':
            cols.append('EXPPass')
        elif column == 'Att.1':
            cols.append('RushAtt')
        elif column == 'Yds.2':
            cols.append('RushYds')
        elif column == 'TD.1':
            cols.append('RushTDs')
        elif column == 'Lng_y':
            cols.append('RushLng')
        elif column == 'Y/A_x':
            cols.append('Y/RushA')
        elif column == 'Y/G_y':
            cols.append('RushY/G')
        elif column == '1stD.2':
            cols.append('Rush1stD')
        elif column == 'EXP':
            cols.append('EXPRush')
        elif column == 'Yds.3':
            cols.append('PenYds')
        elif column == 'EXP_x':
            cols.append('EXPTot')
        else:
            cols.append(column)
    df.columns = cols
    
    # Change dtypes of columns to numeric
    columns = df.columns[2:]
    for col in columns:
        if '%' in col:
            df[col] = df[col].str.rstrip('%').astype('float') / 100.0
        else:
            df[col] = pd.to_numeric(df[col],errors='coerce')
    # Add year column and fill null values with 0
    df['Year'] = year
    df = df.fillna(0)
    # Create Team ID column
    teamID = []
    for index, row in df.iterrows():
        teamID.append(row['Abbr'] + str(row['Year']))
    df['TmID'] = teamID
    
    return df

# %%
def createFantDB(startYear,endYear,function):
    # Import dependencies
    import pandas as pd
    database = pd.DataFrame()
    years = []
    # Iterates through years specified
    for year in range(startYear, endYear + 1):
        years.append(year)
    for year in years:
        database = database.append(function(year))
    return database

# %%
def createAdvDB(startYear,endYear,function,PerGame=False):
    # Import dependencies
    import pandas as pd
    flag=PerGame
    database = pd.DataFrame()
    years = []
    # Iterates through years specified
    for year in range(startYear, endYear + 1):
        years.append(year)
    for year in years:
        database = database.append(function(year,flag))
    return database

# %%
def cleanffball(year):
    # Import dependencies
    import pandas as pd
    #Scrape and create dataframe from website
    url = f'https://www.pro-football-reference.com/years/{year}/fantasy.htm'
    df = pd.read_html(url,header=1)[0]
    # Drop unnecessary columns and clean up the dataframe
    df = df.drop(['Rk','VBD','FantPt','DKPt','FDPt'],axis=1)
    df = df[df['FantPos'].notna()]
    df = df[df['FantPos'] != 'FantPos']
    df['Y/A'] = df['Y/A'].fillna(0)
    df['Y/R'] = df['Y/R'].fillna(0)
    df['2PM'] = df['2PM'].fillna(0)
    df['2PP'] = df['2PP'].fillna(0)
    df = df.replace('\+','',regex=True).astype(object)
    df = df.replace('\*','',regex=True).astype(object)
    # Strips extra whitespace from end of player column
    df['Player'] = df['Player'].str.rstrip()
    # Change dtypes of columns to numeric
    columns = df.columns[3:]
    for col in columns:
        df[col] = pd.to_numeric(df[col],errors='coerce')
    # Create overall rank column
    df['PPR_OvRank'] = df['PPR'].rank(method='first',ascending=False)
    # Drop columns and null values
    df = df.drop(columns=['OvRank'],axis=1)
    df = df.dropna()
    # Create year and PPG columns
    df['Year'] = year
    df['PPG'] = df['PPR'] / df['G']
    df['PPG'] = df['PPG'].round(decimals = 3)
    # Edits name for uniformity year over year
    df['Player'] = df.Player.str.replace('[^a-zA-Z]', '', regex = True)
    # Creates unique Player ID and Team ID to make stats for different years easier to see
    playerID = []
    for index, row in df.iterrows():
        playerID.append(row['Player'] + str(row['Year']))
    df['PlID'] = playerID
    
    teamID = []
    for index, row in df.iterrows():
        teamID.append(row['Tm'] + str(row['Year']))
    df['TmID'] = teamID
    
    return df

# %%
def cleanDB(database):
    import pandas as pd
    cols = []
    for column in database.columns:
        if column == 'FantPos':
            cols.append('Pos')
        elif column == 'Yds':
            cols.append('PassYds')
        elif column == 'Yds.1':
            cols.append('RushYds')
        elif column == 'Yds.2':
            cols.append('RecYds')
        elif column == 'Att':
            cols.append('PassAtt')
        elif column == 'Att.1':
            cols.append('RushAtt')
        elif column == 'TD':
            cols.append('PassTD')
        elif column == 'TD.1':
            cols.append('RushTD')
        elif column == 'TD.2':
            cols.append('RecTD')
        elif column == 'TD.3':
            cols.append('TotTD')
        else:
            cols.append(column)

    database.columns = cols
    
    listOfColumns = ['Cmp','PassAtt','PassYds','PassTD','Int','RushAtt','RushYds',
                     'Y/A','RushTD','Tgt','Rec','RecYds','Y/R','RecTD','Fmb',
                     'FL','TotTD','2PM','2PP','PPR','PosRank','PPR_OvRank','Year',
                     'PPG']
    
    # Creates columns for stats per game
    for column in listOfColumns:
        if column == 'Y/A':
            newColumn = 'RushYds/Att'
            database[newColumn] = database[column]
        elif column == 'Y/R':
            newColumn = 'Yds/Rec'
            database[newColumn] = database[column]
        elif column == 'PPR':
            newColumn = 'FPts'
            database[newColumn] = database[column]
        elif column == 'PosRank':
            newColumn = 'PosRk'
            database[newColumn] = database[column]
        elif column == 'PPR_OvRank':
            newColumn = 'OvRank'
            database[newColumn] = database[column]
        elif column == 'Year':
            newColumn = 'Yr'
            database[newColumn] = database[column]
        elif column == 'PPG':
            newColumn = 'PPR/G'
            database[newColumn] = database[column]
        else:
            newColumn = column + '/G'
            database[newColumn] = (pd.to_numeric(database[column]) / pd.to_numeric(database['G']))
            database[newColumn] = database[newColumn].round(decimals = 3)
            
    database = database.drop(columns = listOfColumns)
    database.loc[(database['Pos'] == 'QB') & ((database['GS'] / database['G']) >= .75) & (database['GS'] >= 5), 'Starter'] = 1
    database.loc[(database['Pos'] == 'QB') & ((database['GS'] / database['G']) < .75) & (database['GS'] < 5), 'Starter'] = 0 
    database['Starter'] = database['Starter'].fillna(0)
    
    database = database.sort_values(by = ['Player','Yr'], ascending = [True,False])
    nextYearPPG = []
    nextYearStart = []
    lastPlayer = 'NaN'
    lastPlayerPPG = 'NaN'
    lastPlayerStart = 'NaN'

    for index, row in database.iterrows():
            player = row['Player']
            if lastPlayer == player:
                nextYearPPG.append(lastPlayerPPG)
                nextYearStart.append(lastPlayerStart)
            else:
                nextYearPPG.append('NaN')
                nextYearStart.append('NaN')
            lastPlayer = row['Player']
            lastPlayerPPG = row['PPR/G']
            lastPlayerStart = row['Starter']
    
    database['Next_Yr_PPG'] = nextYearPPG
    database['Next_Yr_PPG'] = pd.to_numeric(database['Next_Yr_PPG'],errors='coerce')
    database['Next_Yr_Starter'] = nextYearStart
    database['Next_Yr_Starter'] = pd.to_numeric(database['Next_Yr_Starter'],errors='coerce',downcast='integer')
    database = database.reset_index(drop = True)
    return database

# %%
def scrapeAdvancedPass(year,PerGame=False):
    from splinter import Browser
    from bs4 import BeautifulSoup as soup
    from webdriver_manager.chrome import ChromeDriverManager
    import pandas as pd
    from functools import reduce
    # Set up Splinter
    executable_path = {'executable_path': ChromeDriverManager().install()}
    browser = Browser('chrome', **executable_path, headless=True)
    # Visit the AdvancedStats to Scrape site
    url = f'https://www.pro-football-reference.com/years/{year}/passing_advanced.htm'
    browser.visit(url)
    # Parse the HTML
    html = browser.html
    html_soup = soup(html, 'html.parser')
    browser.quit()
    try:
        
        df1 = html_soup.find('table', {"id" : 'advanced_air_yards'})
        df2 = html_soup.find('table', {"id" : 'advanced_accuracy'})
        df3 = html_soup.find('table', {"id" : 'advanced_pressure'})
        df4 = html_soup.find('table', {"id" : 'advanced_play_type'})

        df1 = pd.read_html(str(df1),header=1)[0]
        df2 = pd.read_html(str(df2),header=1)[0]
        df3 = pd.read_html(str(df3),header=1)[0]
        df4 = pd.read_html(str(df4),header=1)[0]
    
        data_frames = [df1, df2, df3, df4]
        df = reduce(lambda  left,right: pd.merge(left,right,on=['Player'],
                                                    how='outer'), data_frames)
        df = df[df['Player'] != 'Player']
        df = df[df['Player'].notna()]
        df = df.replace('\/','',regex=True).astype(object)
        df = df.replace('^qb','QB',regex=True).astype(object)
        df = df.replace('^rb','RB',regex=True).astype(object)
        df = df.replace('^wr','WR',regex=True).astype(object)
        df = df.replace('^te','TE',regex=True).astype(object)
        df = df.replace('\+','',regex=True).astype(object)
        df = df.replace('\*','',regex=True).astype(object)
        columns = ['Player','Tm_x','Pos_x','Age_x','G_x','GS_x','Cmp_x','Att_x','Yds_x','IAY',
                   'IAY/PA','CAY','CAY/Cmp','CAY/PA','YAC','YAC/Cmp','Bats','ThAwy',
                   'Spikes','Drops','Drop%','BadTh','Bad%','OnTgt','OnTgt%','Sk',
                   'PktTime','Bltz','Hrry','Prss','Prss%','Scrm','Yds/Scr','Plays',
                   'Yds.1','PassAtt','PassYds','RushAtt','RushYds', 'PassAtt.1', 'PassYds.1']

        df = df[columns]
        df = df.loc[:,~df.columns.duplicated()]
        cols = []
        for column in df.columns:
            if column == 'Tm_x':
                cols.append('Tm')
            elif column == 'Pos_x':
                cols.append('Pos')
            elif column == 'Age_x':
                cols.append('Age')
            elif column == 'G_x':
                cols.append('G')
            elif column == 'GS_x':
                cols.append('GS')
            elif column == 'Cmp_x':
                cols.append('Cmp')
            elif column == 'Att_x':
                cols.append('Att')
            elif column == 'Yds_x':
                cols.append('Yds')
            elif column == 'Yds.1':
                cols.append('RPO_Yds')
            elif column == 'PassAtt':
                cols.append('RPO_PassAtt')
            elif column == 'PassYds':
                cols.append('RPO_PassYds')
            elif column == 'RushAtt':
                cols.append('RPO_RushAtt')
            elif column == 'RushYds':
                cols.append('RPO_RushYds')
            elif column == 'PassAtt.1':
                cols.append('PA_PassAtt')
            elif column == 'PassYds.1':
                cols.append('PA_PassYds')
            else:
                cols.append(column)

        df.columns = cols
        df = df.fillna(0)
        df = df[df['Pos'] != 'k']
        df = df[df['Pos'] != 'p']
        if PerGame is False:
            columns = df.columns[3:]
            for col in columns:
                if '%' in col:
                    df[col] = df[col].str.rstrip('%').astype('float') / 100.0
                else:
                    df[col] = pd.to_numeric(df[col],errors='coerce')
        else:
            columns = df.columns[3:]
            for col in columns:
                if '%' in col:
                    df[col] = df[col].str.rstrip('%').astype('float') / 100.0
                else:
                    df[col] = pd.to_numeric(df[col],errors='coerce')
                    
            listOfColumns = ['Cmp','Att','Yds','IAY','IAY/PA','CAY','CAY/Cmp',
                             'CAY/PA','YAC','YAC/Cmp','Bats','ThAwy','Spikes','Drops',
                             'Drop%','BadTh','Bad%','OnTgt','OnTgt%','Sk','PktTime',
                             'Bltz','Hrry','Prss','Prss%','Scrm','Yds/Scr','Plays',
                             'RPO_Yds','RPO_PassAtt','RPO_PassYds','RPO_RushAtt',
                             'RPO_RushYds', 'PA_PassAtt','PA_PassYds']
        
            for column in listOfColumns:
                if column == 'IAY/PA':
                    newColumn = 'IAirYds/PassA'
                    df[newColumn] = df[column]
                elif column == 'CAY/Cmp':
                    newColumn = 'CAirYds/Cmp'
                    df[newColumn] = df[column]
                elif column == 'CAY/PA':
                    newColumn = 'CAirYds/PassA'
                    df[newColumn] = df[column]
                elif column == 'YAC/Cmp':
                    newColumn = 'YdsAC/Cmp'
                    df[newColumn] = df[column]
                elif column == 'Drop%':
                    newColumn = 'Drp%'
                    df[newColumn] = df[column]
                elif column == 'Bad%':
                    newColumn = 'BadTh%'
                    df[newColumn] = df[column]
                elif column == 'OnTgt%':
                    newColumn = 'OnTarg%'
                    df[newColumn] = df[column]
                elif column == 'PktTime':
                    newColumn = 'PockTime'
                    df[newColumn] = df[column]
                elif column == 'Prss%':
                    newColumn = 'Press%'
                    df[newColumn] = df[column]
                elif column == 'Yds/Scr':
                    newColumn = 'Yds/Scram'
                    df[newColumn] = df[column]
                else:
                    newColumn = column + '/G'
                    df[newColumn] = (pd.to_numeric(df[column]) / pd.to_numeric(df['G']))
                    df[newColumn] = df[newColumn].round(decimals = 3)
            df = df.drop(columns = listOfColumns)
                
        df['Year'] = year
        df['Player'] = df.Player.str.replace('[^a-zA-Z]', '', regex = True)
        # creates unique player ID to make stats for different years easier to see
        playerID = []
        for index, row in df.iterrows():
            playerID.append(row['Player'] + str(row['Year']))
        df['ID'] = playerID
        
        teamID = []
        for index, row in df.iterrows():
            teamID.append(row['Tm'] + str(row['Year']))
        df['TmID'] = teamID
        
    except:
        
        df1 = html_soup.find('table', {"id" : 'advanced_air_yards'})
        df2 = html_soup.find('table', {"id" : 'advanced_accuracy'})
        df3 = html_soup.find('table', {"id" : 'advanced_pressure'})

        df1 = pd.read_html(str(df1),header=1)[0]
        df2 = pd.read_html(str(df2),header=1)[0]
        df3 = pd.read_html(str(df3),header=1)[0]
    
        data_frames = [df1, df2, df3]
        df = reduce(lambda  left,right: pd.merge(left,right,on=['Player'],
                                                    how='outer'), data_frames)
        df = df[df['Player'] != 'Player']
        df = df[df['Player'].notna()]
        df = df.replace('\/','',regex=True).astype(object)
        df = df.replace('^qb','QB',regex=True).astype(object)
        df = df.replace('^rb','RB',regex=True).astype(object)
        df = df.replace('^wr','WR',regex=True).astype(object)
        df = df.replace('^te','TE',regex=True).astype(object)
        df = df.replace('\+','',regex=True).astype(object)
        df = df.replace('\*','',regex=True).astype(object)
        columns = ['Player','Tm_x','Pos_x','Age_x','G_x','GS_x','Cmp_x','Att_x','Yds_x','IAY',
                   'IAY/PA','CAY','CAY/Cmp','CAY/PA','YAC','YAC/Cmp','ThAwy',
                   'Spikes','Drops','Drop%','BadTh','Bad%','Sk',
                   'PktTime','Bltz','Hrry','Prss','Prss%','Scrm','Yds/Scr']

        df = df[columns]
        df = df.loc[:,~df.columns.duplicated()]
        cols = []
        for column in df.columns:
            if column == 'Tm_x':
                cols.append('Tm')
            elif column == 'Pos_x':
                cols.append('Pos')
            elif column == 'Age_x':
                cols.append('Age')
            elif column == 'G_x':
                cols.append('G')
            elif column == 'GS_x':
                cols.append('GS')
            elif column == 'Cmp_x':
                cols.append('Cmp')
            elif column == 'Att_x':
                cols.append('Att')
            elif column == 'Yds_x':
                cols.append('Yds')
            else:
                cols.append(column)

        df.columns = cols
        df = df.fillna(0)
        df = df[df['Pos'] != 'k']
        df = df[df['Pos'] != 'p']
        
        if PerGame is False:
            columns = df.columns[3:]
            for col in columns:
                if '%' in col:
                    df[col] = df[col].str.rstrip('%').astype('float') / 100.0
                else:
                    df[col] = pd.to_numeric(df[col],errors='coerce')
        else:
            columns = df.columns[3:]
            for col in columns:
                if '%' in col:
                    df[col] = df[col].str.rstrip('%').astype('float') / 100.0
                else:
                    df[col] = pd.to_numeric(df[col],errors='coerce')
                    
            listOfColumns = ['Cmp','Att','Yds','IAY','IAY/PA','CAY','CAY/Cmp',
                             'CAY/PA','YAC','YAC/Cmp','Bats','ThAwy','Spikes','Drops',
                             'Drop%','BadTh','Bad%','OnTgt','OnTgt%','Sk','PktTime',
                             'Bltz','Hrry','Prss','Prss%','Scrm','Yds/Scr']
        
            for column in listOfColumns:
                if column == 'IAY/PA':
                    newColumn = 'IAirYds/PassA'
                    df[newColumn] = df[column]
                elif column == 'CAY/Cmp':
                    newColumn = 'CAirYds/Cmp'
                    df[newColumn] = df[column]
                elif column == 'CAY/PA':
                    newColumn = 'CAirYds/PassA'
                    df[newColumn] = df[column]
                elif column == 'YAC/Cmp':
                    newColumn = 'YdsAC/Cmp'
                    df[newColumn] = df[column]
                elif column == 'Drop%':
                    newColumn = 'Drp%'
                    df[newColumn] = df[column]
                elif column == 'Bad%':
                    newColumn = 'BadTh%'
                    df[newColumn] = df[column]
                elif column == 'OnTgt%':
                    newColumn = 'OnTarg%'
                    df[newColumn] = df[column]
                elif column == 'PktTime':
                    newColumn = 'PockTime'
                    df[newColumn] = df[column]
                elif column == 'Prss%':
                    newColumn = 'Press%'
                    df[newColumn] = df[column]
                elif column == 'Yds/Scr':
                    newColumn = 'Yds/Scram'
                    df[newColumn] = df[column]
                else:
                    newColumn = column + '/G'
                    df[newColumn] = (pd.to_numeric(df[column]) / pd.to_numeric(df['G']))
                    df[newColumn] = df[newColumn].round(decimals = 3)
            df = df.drop(columns = listOfColumns)
                
        df['Year'] = year
        df['Player'] = df.Player.str.replace('[^a-zA-Z]', '', regex = True)
        # creates unique player ID to make stats for different years easier to see
        playerID = []
        for index, row in df.iterrows():
            playerID.append(row['Player'] + str(row['Year']))
        df['PlID'] = playerID
        
        teamID = []
        for index, row in df.iterrows():
            teamID.append(row['Tm'] + str(row['Year']))
        df['TmID'] = teamID
    
    
    return df

# %%
def scrapeAdvancedRush(year,PerGame=False):
    from splinter import Browser
    from bs4 import BeautifulSoup as soup
    from webdriver_manager.chrome import ChromeDriverManager
    import pandas as pd
    # Set up Splinter
    executable_path = {'executable_path': ChromeDriverManager().install()}
    browser = Browser('chrome', **executable_path, headless=True)
    # Visit the AdvancedStats to Scrape site
    url = f'https://www.pro-football-reference.com/years/{year}/rushing_advanced.htm'
    browser.visit(url)
    # Parse the HTML
    html = browser.html
    html_soup = soup(html, 'html.parser')
    browser.quit()
    
    df = html_soup.find('table', {"id" : 'advanced_rushing'})
    df = pd.read_html(str(df),header=1)[0]
    
    df = df[df['Player'] != 'Player']
    df = df[df['Player'].notna()]
    df = df.replace('\/','',regex=True).astype(object)
    df = df.replace('^qb','QB',regex=True).astype(object)
    df = df.replace('^rb','RB',regex=True).astype(object)
    df = df.replace('^wr','WR',regex=True).astype(object)
    df = df.replace('^te','TE',regex=True).astype(object)
    df = df.replace('\+','',regex=True).astype(object)
    df = df.replace('\*','',regex=True).astype(object)
    columns = ['Player','Tm','Pos','Age','G','GS','Att','Yds','1D',
               'YBC','YBC/Att','YAC','YAC/Att','BrkTkl','Att/Br']

    df = df[columns]

    df = df.fillna(0)
    df = df[df['Pos'] != 'k']
    df = df[df['Pos'] != 'p']
    if PerGame is False:
        columns = df.columns[3:]
        for col in columns:
            df[col] = pd.to_numeric(df[col],errors='coerce')
    else:
        columns = df.columns[3:]
        for col in columns:
            df[col] = pd.to_numeric(df[col],errors='coerce')
            
        listOfColumns = ['Att','Yds','1D','YBC','YBC/Att','YAC',
                         'YAC/Att','BrkTkl','Att/Br']
        
        for column in listOfColumns:
            if column == 'YBC/Att':
                newColumn = 'YBCont/A'
                df[newColumn] = df[column]
            elif column == 'YAC/Att':
                newColumn = 'YACont/A'
                df[newColumn] = df[column]
            elif column == 'Att/Br':
                newColumn = 'Att/BrTk'
                df[newColumn] = df[column]
            else:
                newColumn = column + '/G'
                df[newColumn] = (pd.to_numeric(df[column]) / pd.to_numeric(df['G']))
                df[newColumn] = df[newColumn].round(decimals = 3)
        df = df.drop(columns = listOfColumns)
    
    df['Year'] = year
    df['Player'] = df.Player.str.replace('[^a-zA-Z]', '', regex = True)
    # creates unique player ID to make stats for different years easier to see
    playerID = []
    for index, row in df.iterrows():
        playerID.append(row['Player'] + str(row['Year']))
    df['PlID'] = playerID
    
    teamID = []
    for index, row in df.iterrows():
        teamID.append(row['Tm'] + str(row['Year']))
    df['TmID'] = teamID
    
    browser.quit()
    
    return df

# %%
def scrapeAdvancedRec(year,PerGame=False):
    from splinter import Browser
    from bs4 import BeautifulSoup as soup
    from webdriver_manager.chrome import ChromeDriverManager
    import pandas as pd
    # Set up Splinter
    executable_path = {'executable_path': ChromeDriverManager().install()}
    browser = Browser('chrome', **executable_path, headless=True)
    # Visit the AdvancedStats to Scrape site
    url = f'https://www.pro-football-reference.com/years/{year}/receiving_advanced.htm'
    browser.visit(url)
    # Parse the HTML
    html = browser.html
    html_soup = soup(html, 'html.parser')
    browser.quit()
    
    df = html_soup.find('table', {"id" : 'advanced_receiving'})
    df = pd.read_html(str(df),header=0)[0]
    
    df = df[df['Player'] != 'Player']
    df = df[df['Player'].notna()]
    df = df.replace('\/','',regex=True).astype(object)
    df = df.replace('^qb','QB',regex=True).astype(object)
    df = df.replace('^rb','RB',regex=True).astype(object)
    df = df.replace('^wr','WR',regex=True).astype(object)
    df = df.replace('^te','TE',regex=True).astype(object)
    df = df.replace('\+','',regex=True).astype(object)
    df = df.replace('\*','',regex=True).astype(object)
    columns = ['Player','Tm','Pos','Age','G','GS','Tgt','Rec','Yds','TD','1D','YBC','YBC/R',
               'YAC','YAC/R','ADOT','BrkTkl','Rec/Br','Drop','Drop%','Int','Rat']

    df = df[columns]

    df = df.fillna(0)
    df = df[df['Pos'] != 'k']
    df = df[df['Pos'] != 'p']
    if PerGame is False:
        columns = df.columns[3:]
        for col in columns:
            if '%' in col:
                df[col] = df[col].str.rstrip('%').astype('float') / 100.0
            else:
                df[col] = pd.to_numeric(df[col],errors='coerce')
    else:
        columns = df.columns[3:]
        for col in columns:
            if '%' in col:
                df[col] = df[col].str.rstrip('%').astype('float') / 100.0
            else:
                df[col] = pd.to_numeric(df[col],errors='coerce')
        
        listOfColumns = ['Tgt','Rec','Yds','TD','1D','YBC','YBC/R','YAC','YAC/R',
                         'ADOT','BrkTkl','Rec/Br','Drop','Drop%','Int','Rat']
        
        for column in listOfColumns:
            if column == 'YBC/R':
                newColumn = 'YdsBC/Rec'
                df[newColumn] = df[column]
            elif column == 'YAC/R':
                newColumn = 'YdsAC/Rec'
                df[newColumn] = df[column]
            elif column == 'ADOT':
                newColumn = 'AvgDOT'
                df[newColumn] = df[column]
            elif column == 'Rec/Br':
                newColumn = 'Rec/BrTk'
                df[newColumn] = df[column]
            elif column == 'Drop%':
                newColumn = 'Drp%'
                df[newColumn] = df[column]
            elif column == 'Rat':
                newColumn = 'PassRat'
                df[newColumn] = df[column]
            else:
                newColumn = column + '/G'
                df[newColumn] = (pd.to_numeric(df[column]) / pd.to_numeric(df['G']))
                df[newColumn] = df[newColumn].round(decimals = 3)
        df = df.drop(columns = listOfColumns)
    
    
    df['Year'] = year
    df['Player'] = df.Player.str.replace('[^a-zA-Z]', '', regex = True)
    # creates unique player ID to make stats for different years easier to see
    playerID = []
    for index, row in df.iterrows():
        playerID.append(row['Player'] + str(row['Year']))
    df['PlID'] = playerID
    
    teamID = []
    for index, row in df.iterrows():
        teamID.append(row['Tm'] + str(row['Year']))
    df['TmID'] = teamID
    
    return df

# %%
def positions(year):
    import pandas as pd
    #Scrape and create dataframe from website
    url = f'https://www.pro-football-reference.com/years/{year}/fantasy.htm'
    df = pd.read_html(url,header=1)[0]
    # Drop unnecessary columns and clean up the dataframe
    df = df[['Player','Tm','FantPos']]
    df = df[df['FantPos'].notna()]
    df = df[df['FantPos'] != 'FantPos']
    df = df.replace('\+','',regex=True).astype(object)
    df = df.replace('\*','',regex=True).astype(object)
    # Strips extra whitespace from end of player column
    df['Player'] = df['Player'].str.rstrip()
    df = df.dropna()
    # Create year and PPG columns
    df['Year'] = year
    # Edits name for uniformity year over year
    df['Player'] = df.Player.str.replace('[^a-zA-Z]', '', regex = True)
    # Creates unique Player ID and Team ID to make stats for different years easier to see
    playerID = []
    for index, row in df.iterrows():
        playerID.append(row['Player'] + str(row['Year']))
    df['PlID'] = playerID
    
    teamID = []
    for index, row in df.iterrows():
        teamID.append(row['Tm'] + str(row['Year']))
    df['TmID'] = teamID
    
    return df

# %%
advPass = createAdvDB(2019,2021,scrapeAdvancedPass)
advPassGame = createAdvDB(2019,2021,scrapeAdvancedPass,PerGame=True)
advRush = createAdvDB(2019,2021,scrapeAdvancedRush)
advRushGame = createAdvDB(2019,2021,scrapeAdvancedRush,PerGame=True)
advRec = createAdvDB(2019,2021,scrapeAdvancedRec)
advRecGame = createAdvDB(2019,2021,scrapeAdvancedRec,PerGame=True)

#fantasy = cleanDB(createDB(2012,2021,cleanffball))

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
positions = createFantDB(2012,2021,positions)
positions
# Out:
#                      Player   Tm FantPos  Year                        PlID  \
# 0            AdrianPeterson  MIN      RB  2012          AdrianPeterson2012
# 1                DougMartin  TAM      RB  2012              DougMartin2012
# 2               ArianFoster  HOU      RB  2012             ArianFoster2012
# 3             MarshawnLynch  SEA      RB  2012           MarshawnLynch2012
# 4              AlfredMorris  WAS      RB  2012            AlfredMorris2012
# 5                   RayRice  BAL      RB  2012                 RayRice2012
# 6             CalvinJohnson  DET      WR  2012           CalvinJohnson2012
# 7           BrandonMarshall  CHI      WR  2012         BrandonMarshall2012
# 8                 CJSpiller  BUF      RB  2012               CJSpiller2012
# 9                 DrewBrees  NOR      QB  2012               DrewBrees2012
# 10             AaronRodgers  GNB      QB  2012            AaronRodgers2012
# 11                 TomBrady  NWE      QB  2012                TomBrady2012
# 12                DezBryant  DAL      WR  2012               DezBryant2012
# 13            JamaalCharles  KAN      RB  2012           JamaalCharles2012
# 14          TrentRichardson  CLE      RB  2012         TrentRichardson2012
# 15                FrankGore  SFO      RB  2012               FrankGore2012
# 16                  AJGreen  CIN      WR  2012                 AJGreen2012
# 17             StevanRidley  NWE      RB  2012            StevanRidley2012
# 18          DemaryiusThomas  DEN      WR  2012         DemaryiusThomas2012
# 19                CamNewton  CAR      QB  2012               CamNewton2012
# 20           VincentJackson  TAM      WR  2012          VincentJackson2012
# 21         RobertGriffinIII  WAS      QB  2012        RobertGriffinIII2012
# 22               EricDecker  DEN      WR  2012              EricDecker2012
# 23             AndreJohnson  HOU      WR  2012            AndreJohnson2012
# 24               JulioJones  ATL      WR  2012              JulioJones2012
# 25                MattForte  CHI      RB  2012               MattForte2012
# 26            PeytonManning  DEN      QB  2012           PeytonManning2012
# 27             ChrisJohnson  TEN      RB  2012            ChrisJohnson2012
# 28               RoddyWhite  ATL      WR  2012              RoddyWhite2012
# 30              JimmyGraham  NOR      TE  2012             JimmyGraham2012
# 31               ReggieBush  MIA      RB  2012              ReggieBush2012
# 32                 MattRyan  ATL      QB  2012                MattRyan2012
# 33                WesWelker  NWE      WR  2012               WesWelker2012
# 34           MarquesColston  NOR      WR  2012          MarquesColston2012
# 35              ShonnGreene  NYJ      RB  2012             ShonnGreene2012
# 36               VictorCruz  NYG      WR  2012              VictorCruz2012
# 37            RobGronkowski  NWE      TE  2012           RobGronkowski2012
# 38          MichaelCrabtree  SFO      WR  2012         MichaelCrabtree2012
# 39            StevenJackson  STL      RB  2012           StevenJackson2012
# 40             TonyGonzalez  ATL      TE  2012            TonyGonzalez2012
# 41              ReggieWayne  IND      WR  2012             ReggieWayne2012
# 42               JamesJones  GNB      WR  2012              JamesJones2012
# 43              RandallCobb  GNB      WR  2012             RandallCobb2012
# 44            MichaelTurner  ATL      RB  2012           MichaelTurner2012
# 45            AhmadBradshaw  NYG      RB  2012           AhmadBradshaw2012
# 46             MikeWilliams  TAM      WR  2012            MikeWilliams2012
# 47              HeathMiller  PIT      TE  2012             HeathMiller2012
# 48      BenJarvusGreenEllis  CIN      RB  2012     BenJarvusGreenEllis2012
# 49            MikelLeshoure  DET      RB  2012           MikelLeshoure2012
# 50              LeSeanMcCoy  PHI      RB  2012             LeSeanMcCoy2012
# 51                 TonyRomo  DAL      QB  2012                TonyRomo2012
# 52            RussellWilson  SEA      QB  2012           RussellWilson2012
# 53              JasonWitten  DAL      TE  2012             JasonWitten2012
# 54               AndrewLuck  IND      QB  2012              AndrewLuck2012
# 55          MatthewStafford  DET      QB  2012         MatthewStafford2012
# 56            DarrenSproles  NOR      RB  2012           DarrenSproles2012
# 57             SteveSmithSr  CAR      WR  2012            SteveSmithSr2012
# 58               LanceMoore  NOR      WR  2012              LanceMoore2012
# 59             SteveJohnson  BUF      WR  2012            SteveJohnson2012
# 61              CecilShorts  JAX      WR  2012             CecilShorts2012
# 62                GregOlsen  CAR      TE  2012               GregOlsen2012
# 63                 TYHilton  IND      WR  2012                TYHilton2012
# 64              TorreySmith  BAL      WR  2012             TorreySmith2012
# 65         DeAngeloWilliams  CAR      RB  2012        DeAngeloWilliams2012
# 66              DennisPitta  BAL      TE  2012             DennisPitta2012
# 67              MikeWallace  PIT      WR  2012             MikeWallace2012
# 68              OwenDaniels  HOU      TE  2012             OwenDaniels2012
# 69              MilesAustin  DAL      WR  2012             MilesAustin2012
# 70              KyleRudolph  MIN      TE  2012             KyleRudolph2012
# 71             BrandonMyers  OAK      TE  2012            BrandonMyers2012
# 72             JeremyMaclin  PHI      WR  2012            JeremyMaclin2012
# 73          JermaineGresham  CIN      TE  2012         JermaineGresham2012
# 74             BrandonLloyd  NWE      WR  2012            BrandonLloyd2012
# 75           JustinBlackmon  JAX      WR  2012          JustinBlackmon2012
# 76               AndyDalton  CIN      QB  2012              AndyDalton2012
# 78              JordyNelson  GNB      WR  2012             JordyNelson2012
# 79            DannyWoodhead  NWE      RB  2012           DannyWoodhead2012
# 80              JoshFreeman  TAM      QB  2012             JoshFreeman2012
# 81                JoeFlacco  BAL      QB  2012               JoeFlacco2012
# 82               EliManning  NYG      QB  2012              EliManning2012
# 83              SamBradford  STL      QB  2012             SamBradford2012
# 84               MattSchaub  HOU      QB  2012              MattSchaub2012
# 85             CarsonPalmer  OAK      QB  2012            CarsonPalmer2012
# 86        BenRoethlisberger  PIT      QB  2012       BenRoethlisberger2012
# 87          RyanFitzpatrick  BUF      QB  2012         RyanFitzpatrick2012
# 88             PhilipRivers  SDG      QB  2012            PhilipRivers2012
# 89          ChristianPonder  MIN      QB  2012         ChristianPonder2012
# 90                JayCutler  CHI      QB  2012               JayCutler2012
# 92            RyanTannehill  MIA      QB  2012           RyanTannehill2012
# 93          ColinKaepernick  SFO      QB  2012         ColinKaepernick2012
# 94            BrandonWeeden  CLE      QB  2012           BrandonWeeden2012
# 95              MichaelVick  PHI      QB  2012             MichaelVick2012
# 96               JakeLocker  TEN      QB  2012              JakeLocker2012
# 97                AlexSmith  SFO      QB  2012               AlexSmith2012
# 98             AnquanBoldin  BAL      WR  2012            AnquanBoldin2012
# 99               SidneyRice  SEA      WR  2012              SidneyRice2012
# 100             MarkSanchez  NYJ      QB  2012             MarkSanchez2012
# 101           DenariusMoore  OAK      WR  2012           DenariusMoore2012
# 102              GoldenTate  SEA      WR  2012              GoldenTate2012
# 103             VickBallard  IND      RB  2012             VickBallard2012
# 104               ChadHenne  JAX      QB  2012               ChadHenne2012
# 105           WillisMcGahee  DEN      RB  2012           WillisMcGahee2012
# 106           BrianHartline  MIA      WR  2012           BrianHartline2012
# 107             MalcomFloyd  SDG      WR  2012             MalcomFloyd2012
# 108          DarrenMcFadden  OAK      RB  2012          DarrenMcFadden2012
# 109           DeMarcoMurray  DAL      RB  2012           DeMarcoMurray2012
# 110              JoshGordon  CLE      WR  2012              JoshGordon2012
# 111            AndreRoberts  ARI      WR  2012            AndreRoberts2012
# 112        DanarioAlexander  SDG      WR  2012        DanarioAlexander2012
# 113            AntonioBrown  PIT      WR  2012            AntonioBrown2012
# 114             PercyHarvin  MIN      WR  2012             PercyHarvin2012
# 115             SantanaMoss  WAS      WR  2012             SantanaMoss2012
# 116              JoiqueBell  DET      RB  2012              JoiqueBell2012
# 117         LarryFitzgerald  ARI      WR  2012         LarryFitzgerald2012
# 118           BrandonGibson  STL      WR  2012           BrandonGibson2012
# 119          NateWashington  TEN      WR  2012          NateWashington2012
# 120             RyanMathews  SDG      RB  2012             RyanMathews2012
# 121             DonnieAvery  IND      WR  2012             DonnieAvery2012
# 123              AndreBrown  NYG      RB  2012              AndreBrown2012
# 124            JeremyKerley  NYJ      WR  2012            JeremyKerley2012
# 125              DwayneBowe  KAN      WR  2012              DwayneBowe2012
# 126            AntonioGates  SDG      TE  2012            AntonioGates2012
# 127           BrandonLaFell  CAR      WR  2012           BrandonLaFell2012
# 128            PierreThomas  NOR      RB  2012            PierreThomas2012
# 129           BlaineGabbert  JAX      QB  2012           BlaineGabbert2012
# 130            PierreGarcon  WAS      WR  2012            PierreGarcon2012
# 131        MartellusBennett  NYG      TE  2012        MartellusBennett2012
# 132              MarkIngram  NOR      RB  2012              MarkIngram2012
# 133       DarriusHeywardBey  OAK      WR  2012       DarriusHeywardBey2012
# 134              FelixJones  DAL      RB  2012              FelixJones2012
# 135           ScottChandler  BUF      TE  2012           ScottChandler2012
# 136             ChrisGivens  STL      WR  2012             ChrisGivens2012
# 137          KnowshonMoreno  DEN      RB  2012          KnowshonMoreno2012
# 138              GregLittle  CLE      WR  2012              GregLittle2012
# 139         JacquizzRodgers  ATL      RB  2012         JacquizzRodgers2012
# 140             HakeemNicks  NYG      WR  2012             HakeemNicks2012
# 141             MikeTolbert  CAR      RB  2012             MikeTolbert2012
# 142               NickFoles  PHI      QB  2012               NickFoles2012
# 143             VernonDavis  SFO      TE  2012             VernonDavis2012
# 144               KevinKolb  ARI      QB  2012               KevinKolb2012
# 145           KendallWright  TEN      WR  2012           KendallWright2012
# 146              DavoneBess  MIA      WR  2012              DavoneBess2012
# 147          BrandonStokley  DEN      WR  2012          BrandonStokley2012
# 148           DannyAmendola  STL      WR  2012           DannyAmendola2012
# 149              KennyBritt  TEN      WR  2012              KennyBritt2012
# 150             MarcelReece  OAK      RB  2012             MarcelReece2012
# 151             BilalPowell  NYJ      RB  2012             BilalPowell2012
# 152           JonathanDwyer  PIT      RB  2012           JonathanDwyer2012
# 154           DeSeanJackson  PHI      WR  2012           DeSeanJackson2012
# 155             FredJackson  BUF      RB  2012             FredJackson2012
# 156              BryceBrown  PHI      RB  2012              BryceBrown2012
# 157           AndrewHawkins  CIN      WR  2012           AndrewHawkins2012
# 158          AaronHernandez  NWE      TE  2012          AaronHernandez2012
# 159              MattCassel  KAN      QB  2012              MattCassel2012
# 160          LanceKendricks  STL      TE  2012          LanceKendricks2012
# 161           MarcedesLewis  JAX      TE  2012           MarcedesLewis2012
# 162             MichaelBush  CHI      RB  2012             MichaelBush2012
# 163        JermichaelFinley  GNB      TE  2012        JermichaelFinley2012
# 164          MattHasselbeck  TEN      QB  2012          MattHasselbeck2012
# 165             RodStreater  OAK      WR  2012             RodStreater2012
# 166               JaredCook  TEN      TE  2012               JaredCook2012
# 167        LeonardHankerson  WAS      WR  2012        LeonardHankerson2012
# 168             DavidWilson  NYG      RB  2012             DavidWilson2012
# 169              BrentCelek  PHI      TE  2012              BrentCelek2012
# 170              JoshMorgan  WAS      WR  2012              JoshMorgan2012
# 171             DwayneAllen  IND      TE  2012             DwayneAllen2012
# 172        BrandonPettigrew  DET      TE  2012        BrandonPettigrew2012
# 173             IsaacRedman  PIT      RB  2012             IsaacRedman2012
# 174    LaRodStephensHowling  ARI      RB  2012    LaRodStephensHowling2012
# 175            DomenikHixon  NYG      WR  2012            DomenikHixon2012
# 176           KevinOgletree  DAL      WR  2012           KevinOgletree2012
# 177             DallasClark  TAM      TE  2012             DallasClark2012
# 178             DonaldJones  BUF      WR  2012             DonaldJones2012
# 179              JacobTamme  DEN      TE  2012              JacobTamme2012
# 180            DanielThomas  MIA      RB  2012            DanielThomas2012
# 181               BenWatson  CLE      TE  2012               BenWatson2012
# 182            JackieBattle  SDG      RB  2012            JackieBattle2012
# 183            JoelDreessen  DEN      TE  2012            JoelDreessen2012
# 185            MichaelFloyd  ARI      WR  2012            MichaelFloyd2012
# 186              JasonAvant  PHI      WR  2012              JasonAvant2012
# 187           AnthonyFasano  MIA      TE  2012           AnthonyFasano2012
# 188             JacobyJones  BAL      WR  2012             JacobyJones2012
# 189         EmmanuelSanders  PIT      WR  2012         EmmanuelSanders2012
# 190           BernardPierce  BAL      RB  2012           BernardPierce2012
# 191             KevinWalter  HOU      WR  2012             KevinWalter2012
# 192              TitusYoung  DET      WR  2012              TitusYoung2012
# 193        MauriceJonesDrew  JAX      RB  2012        MauriceJonesDrew2012
# 194         DarylRichardson  STL      RB  2012         DarylRichardson2012
# 195             ShaneVereen  NWE      RB  2012             ShaneVereen2012
# 196            GregJennings  GNB      WR  2012            GregJennings2012
# 197               RandyMoss  SFO      WR  2012               RandyMoss2012
# 198         JonathanStewart  CAR      RB  2012         JonathanStewart2012
# 199             DonaldBrown  IND      RB  2012             DonaldBrown2012
# 200             RonnieBrown  SDG      RB  2012             RonnieBrown2012
# 201               AlexGreen  GNB      RB  2012               AlexGreen2012
# 202          MichaelJenkins  MIN      WR  2012          MichaelJenkins2012
# 203           JulianEdelman  NWE      WR  2012           JulianEdelman2012
# 204              ZachMiller  SEA      TE  2012              ZachMiller2012
# 205               JoeMorgan  NOR      WR  2012               JoeMorgan2012
# 206           TonyScheffler  DET      TE  2012           TonyScheffler2012
# 207             DougBaldwin  SEA      WR  2012             DougBaldwin2012
# 208           AlshonJeffery  CHI      WR  2012           AlshonJeffery2012
# 209         MarioManningham  SFO      WR  2012         MarioManningham2012
# 210         TiquanUnderwood  TAM      WR  2012         TiquanUnderwood2012
# 211          JeffCumberland  NYJ      TE  2012          JeffCumberland2012
# 212         DexterMcCluster  KAN      RB  2012         DexterMcCluster2012
# 213            RobertTurbin  SEA      RB  2012            RobertTurbin2012
# 214             BeanieWells  ARI      RB  2012             BeanieWells2012
# 216           KendallHunter  SFO      RB  2012           KendallHunter2012
# 217          RashadJennings  JAX      RB  2012          RashadJennings2012
# 218          TravisBenjamin  CLE      WR  2012          TravisBenjamin2012
# 219              JamesCasey  HOU      RB  2012              JamesCasey2012
# 220              TonyMoeaki  KAN      TE  2012              TonyMoeaki2012
# 221             EarlBennett  CHI      WR  2012             EarlBennett2012
# 222            AustinPettis  STL      WR  2012            AustinPettis2012
# 223           DelanieWalker  SFO      TE  2012           DelanieWalker2012
# 224            ShaunDraughn  KAN      RB  2012            ShaunDraughn2012
# 225               BradSmith  BUF      WR  2012               BradSmith2012
# 226             MikeGoodson  OAK      RB  2012             MikeGoodson2012
# 227            RuebenRandle  NYG      WR  2012            RuebenRandle2012
# 228             MohamedSanu  CIN      QB  2012             MohamedSanu2012
# 229           JustinForsett  HOU      RB  2012           JustinForsett2012
# 230            AnthonyMcCoy  SEA      TE  2012            AnthonyMcCoy2012
# 231            HarryDouglas  ATL      WR  2012            HarryDouglas2012
# 232             LouisMurphy  CAR      WR  2012             LouisMurphy2012
# 233           GarrettGraham  HOU      RB  2012           GarrettGraham2012
# 234            DustinKeller  NYJ      TE  2012            DustinKeller2012
# 235              BradyQuinn  KAN      QB  2012              BradyQuinn2012
# 236            JariusWright  MIN      WR  2012            JariusWright2012
# 237             RyanBroyles  DET      WR  2012             RyanBroyles2012
# 238            NateBurleson  DET      WR  2012            NateBurleson2012
# 239             RileyCooper  PHI      WR  2012             RileyCooper2012
# 240           RonnieHillman  DEN      RB  2012           RonnieHillman2012
# 241             StephenHill  NYJ      WR  2012             StephenHill2012
# 242         AldrickRobinson  WAS      WR  2012         AldrickRobinson2012
# 243                 BenTate  HOU      RB  2012                 BenTate2012
# 244              RobHousler  ARI      TE  2012              RobHousler2012
# 245            CedricBenson  GNB      RB  2012            CedricBenson2012
# 247           BrandonBolden  NWE      RB  2012           BrandonBolden2012
# 248             CobyFleener  IND      TE  2012             CobyFleener2012
# 249            MontellOwens  JAX      RB  2012            MontellOwens2012
# 250           CedricPeerman  CIN      RB  2012           CedricPeerman2012
# 251         JonathanBaldwin  KAN      WR  2012         JonathanBaldwin2012
# 252                TJGraham  BUF      WR  2012                TJGraham2012
# 253         DeveryHenderson  NOR      WR  2012         DeveryHenderson2012
# 254            PeytonHillis  KAN      RB  2012            PeytonHillis2012
# 255            ChazSchilens  NYJ      WR  2012            ChazSchilens2012
# 256             TomCrabtree  GNB      TE  2012             TomCrabtree2012
# 257         MichealSpurlock  2TM      WR  2012         MichealSpurlock2012
# 258            LoganPaulsen  WAS      TE  2012            LoganPaulsen2012
# 259            DwayneHarris  DAL      WR  2012            DwayneHarris2012
# 260             LamarMiller  MIA      RB  2012             LamarMiller2012
# 261        MontarioHardesty  CLE      RB  2012        MontarioHardesty2012
# 262              ChrisIvory  NOR      RB  2012              ChrisIvory2012
# 263           WilliamPowell  ARI      RB  2012           WilliamPowell2012
# 264             JamesStarks  GNB      RB  2012             JamesStarks2012
# 265             TobyGerhart  MIN      RB  2012             TobyGerhart2012
# 266            CraigStevens  TEN      TE  2012            CraigStevens2012
# 267             CharlesClay  MIA      TE  2012             CharlesClay2012
# 268             KirkCousins  WAS      QB  2012             KirkCousins2012
# 269               FredDavis  WAS      TE  2012               FredDavis2012
# 270             KellenDavis  CHI      TE  2012             KellenDavis2012
# 271              KevinSmith  DET      RB  2012              KevinSmith2012
# 272             DavidThomas  NOR      TE  2012             DavidThomas2012
# 273               LanceBall  DEN      RB  2012               LanceBall2012
# 274              ArmonBinns  2TM      WR  2012              ArmonBinns2012
# 275            DeloneCarter  IND      RB  2012            DeloneCarter2012
# 276           RobertMeachem  SDG      WR  2012           RobertMeachem2012
# 278              EddieRoyal  SDG      WR  2012              EddieRoyal2012
# 279             EvanRoyster  WAS      RB  2012             EvanRoyster2012
# 280             JohnSkelton  ARI      QB  2012             JohnSkelton2012
# 281          DamianWilliams  TEN      WR  2012          DamianWilliams2012
# 282             DevinHester  CHI      WR  2012             DevinHester2012
# 283          SantonioHolmes  NYJ      WR  2012          SantonioHolmes2012
# 284             MarvinJones  CIN      WR  2012             MarvinJones2012
# 285           JasonSnelling  ATL      RB  2012           JasonSnelling2012
# 286         MichaelRobinson  SEA      RB  2012         MichaelRobinson2012
# 287           JordanCameron  CLE      TE  2012           JordanCameron2012
# 288              ClayHarbor  PHI      TE  2012              ClayHarbor2012
# 289            DuJuanHarris  GNB      RB  2012            DuJuanHarris2012
# 290          DamarisJohnson  PHI      WR  2012          DamarisJohnson2012
# 291            KyleWilliams  SFO      WR  2012            KyleWilliams2012
# 292             DarrelYoung  WAS      RB  2012             DarrelYoung2012
# 293       RashardMendenhall  PIT      RB  2012       RashardMendenhall2012
# 294              BrianQuick  STL      WR  2012              BrianQuick2012
# 295           JordanShipley  2TM      WR  2012           JordanShipley2012
# 296        LeGarretteBlount  TAM      RB  2012        LeGarretteBlount2012
# 297               RyanGrant  2TM      RB  2012               RyanGrant2012
# 298                JohnKuhn  GNB      RB  2012                JohnKuhn2012
# 299          JorvorskieLane  MIA      RB  2012          JorvorskieLane2012
# 300           TashardChoice  BUF      RB  2012           TashardChoice2012
# 301          BraylonEdwards  2TM      WR  2012          BraylonEdwards2012
# 302              DerekHagan  OAK      WR  2012              DerekHagan2012
# 303           TerrellePryor  OAK      QB  2012           TerrellePryor2012
# 304             ChrisRainey  PIT      RB  2012             ChrisRainey2012
# 305            DanteRosario  SDG      TE  2012            DanteRosario2012
# 306        MohamedMassaquoi  CLE      WR  2012        MohamedMassaquoi2012
# 307           DariusReynaud  TEN      RB  2012           DariusReynaud2012
# 309           JeromeSimpson  MIN      WR  2012           JeromeSimpson2012
# 310             BrandonTate  CIN      WR  2012             BrandonTate2012
# 311              ClydeGates  NYJ      WR  2012              ClydeGates2012
# 312              VontaLeach  BAL      RB  2012              VontaLeach2012
# 313             JoeMcKnight  NYJ      RB  2012             JoeMcKnight2012
# 314            LaVonBrazill  IND      WR  2012            LaVonBrazill2012
# 315             JuronCriner  OAK      WR  2012             JuronCriner2012
# 316               EdDickson  BAL      TE  2012               EdDickson2012
# 317         LaurentRobinson  JAX      WR  2012         LaurentRobinson2012
# 318             LukeStocker  TAM      TE  2012             LukeStocker2012
# 319              MikeThomas  2TM      WR  2012              MikeThomas2012
# 320            RamsesBarden  NYG      WR  2012            RamsesBarden2012
# 321             EarlyDoucet  ARI      WR  2012             EarlyDoucet2012
# 322             JamieHarper  TEN      RB  2012             JamieHarper2012
# 323        JerrichoCotchery  PIT      WR  2012        JerrichoCotchery2012
# 324              WillHeller  DET      TE  2012              WillHeller2012
# 325             JacobHester  DEN      RB  2012             JacobHester2012
# 326              LestarJean  HOU      WR  2012              LestarJean2012
# 327               NilesPaul  WAS      TE  2012               NilesPaul2012
# 328          LeonWashington  SEA      RB  2012          LeonWashington2012
# 329            ArmandoAllen  CHI      RB  2012            ArmandoAllen2012
# 330            AnthonyDixon  SFO      RB  2012            AnthonyDixon2012
# 331            DonaldDriver  GNB      WR  2012            DonaldDriver2012
# 332             WillJohnson  PIT      RB  2012             WillJohnson2012
# 333           KeshawnMartin  HOU      WR  2012           KeshawnMartin2012
# 334          ChrisOgbonnaya  CLE      RB  2012          ChrisOgbonnaya2012
# 335            JalenParmele  JAX      RB  2012            JalenParmele2012
# 336          CurtisBrinkley  SDG      RB  2012          CurtisBrinkley2012
# 337              KrisDurham  DET      WR  2012              KrisDurham2012
# 338             MarlonMoore  MIA      WR  2012             MarlonMoore2012
# 340         DevinAromashodu  MIN      WR  2012         DevinAromashodu2012
# 341              TandonDoss  BAL      WR  2012              TandonDoss2012
# 342           ByronLeftwich  PIT      QB  2012           ByronLeftwich2012
# 343             TyrodTaylor  BAL      QB  2012             TyrodTaylor2012
# 344           JasonCampbell  CHI      QB  2012           JasonCampbell2012
# 345              JedCollins  NOR      RB  2012              JedCollins2012
# 346            BrianLeonard  CIN      RB  2012            BrianLeonard2012
# 347            RyanWilliams  ARI      RB  2012            RyanWilliams2012
# 348           JeremyStewart  OAK      RB  2012           JeremyStewart2012
# 349            CharlieBatch  PIT      QB  2012            CharlieBatch2012
# 350             DeionBranch  NWE      WR  2012             DeionBranch2012
# 351               ShaunHill  DET      QB  2012               ShaunHill2012
# 352          LaMichaelJames  SFO      RB  2012          LaMichaelJames2012
# 353               DionLewis  PHI      RB  2012               DionLewis2012
# 354         RishardMatthews  MIA      TE  2012         RishardMatthews2012
# 355               DannyWare  TAM      RB  2012               DannyWare2012
# 356            GaryBarnidge  CAR      TE  2012            GaryBarnidge2012
# 357              BaronBatch  PIT      RB  2012              BaronBatch2012
# 358              BrianHoyer  ARI      QB  2012              BrianHoyer2012
# 359               ErikLorig  TAM      RB  2012               ErikLorig2012
# 360            MeweldeMoore  IND      RB  2012            MeweldeMoore2012
# 361         MatthewMulligan  STL      TE  2012         MatthewMulligan2012
# 362           JordanNorwood  CLE      WR  2012           JordanNorwood2012
# 363            AnthonyAllen  BAL      RB  2012            AnthonyAllen2012
# 364             ColeBeasley  DAL      WR  2012             ColeBeasley2012
# 365               KevinBoss  KAN      TE  2012               KevinBoss2012
# 366           StanleyHavili  PHI      RB  2012           StanleyHavili2012
# 367            HenryHynoski  NYG      RB  2012            HenryHynoski2012
# 368                JeffKing  ARI      TE  2012                JeffKing2012
# 369             RyanLindley  ARI      QB  2012             RyanLindley2012
# 371             LeonardPope  PIT      TE  2012             LeonardPope2012
# 372                LeeSmith  BUF      WR  2012                LeeSmith2012
# 373              SteveSmith  STL      WR  2012              SteveSmith2012
# 374          ArmantiEdwards  CAR      WR  2012          ArmantiEdwards2012
# 375         TrindonHolliday  2TM      WR  2012         TrindonHolliday2012
# 376             GregMcElroy  NYJ      QB  2012             GregMcElroy2012
# 377            JohnPhillips  DAL      TE  2012            JohnPhillips2012
# 378          KealohaPilares  CAR      WR  2012          KealohaPilares2012
# 379         DonteStallworth  NWE      WR  2012         DonteStallworth2012
# 380                TimTebow  NYJ      TE  2012                TimTebow2012
# 381           MarcusThigpen  MIA      RB  2012           MarcusThigpen2012
# 382             KeithToston  JAX      RB  2012             KeithToston2012
# 383         LawrenceVickers  DAL      RB  2012         LawrenceVickers2012
# 384              JoshCooper  CLE      WR  2012              JoshCooper2012
# 385             LanceDunbar  DAL      RB  2012             LanceDunbar2012
# 386            KevinElliott  JAX      WR  2012            KevinElliott2012
# 387     MichaelHoomanawanui  NWE      TE  2012     MichaelHoomanawanui2012
# 388          PlaxicoBurress  PIT      WR  2012          PlaxicoBurress2012
# 389           StephenBurton  MIN      WR  2012           StephenBurton2012
# 390            OrsonCharles  CIN      TE  2012            OrsonCharles2012
# 391               DrewDavis  ATL      WR  2012               DrewDavis2012
# 392           ThaddeusLewis  CLE      QB  2012           ThaddeusLewis2012
# 393             BruceMiller  SFO      RB  2012             BruceMiller2012
# 394               KyleOrton  DAL      QB  2012               KyleOrton2012
# 395              BearPascoe  NYG      TE  2012              BearPascoe2012
# 396           BrianRobiskie  DET      WR  2012           BrianRobiskie2012
# 397           PhillipTanner  DAL      RB  2012           PhillipTanner2012
# 398           DavidAusberry  OAK      TE  2012           DavidAusberry2012
# 399          DorinDickerson  BUF      RB  2012          DorinDickerson2012
# 400             DanielFells  NWE      WR  2012             DanielFells2012
# 402              JamesHanna  DAL      TE  2012              JamesHanna2012
# 403                ToddHeap  ARI      TE  2012                ToddHeap2012
# 404               ColtMcCoy  CLE      QB  2012               ColtMcCoy2012
# 405               MattMoore  MIA      QB  2012               MattMoore2012
# 406           RichardMurphy  JAX      RB  2012           RichardMurphy2012
# 407              MattSpaeth  CHI      TE  2012              MattSpaeth2012
# 408              MattWillis  DEN      WR  2012              MattWillis2012
# 409               NateByham  TAM      TE  2012               NateByham2012
# 410          TerranceCopper  KAN      WR  2012          TerranceCopper2012
# 411               JasonHill  NYJ      WR  2012               JasonHill2012
# 412           MichaelPalmer  ATL      TE  2012           MichaelPalmer2012
# 413             DeVierPosey  HOU      WR  2012             DeVierPosey2012
# 414           KonradReuland  NYJ      TE  2012           KonradReuland2012
# 415              KahlilBell  2TM      RB  2012              KahlilBell2012
# 416           SteveBreaston  KAN      WR  2012           SteveBreaston2012
# 417            RhettEllison  MIN      RB  2012            RhettEllison2012
# 418            JabarGaffney  MIA      WR  2012            JabarGaffney2012
# 419           RichardGordon  OAK      TE  2012           RichardGordon2012
# 420          BrandonJackson  CLE      RB  2012          BrandonJackson2012
# 421               GregJones  JAX      RB  2012               GregJones2012
# 422            LeRonMcClain  SDG      RB  2012            LeRonMcClain2012
# 423            JamarNewsome  KAN      WR  2012            JamarNewsome2012
# 424              BenObomanu  SEA      WR  2012              BenObomanu2012
# 425               DavidReed  BAL      WR  2012               DavidReed2012
# 426               CyrusGray  KAN      RB  2012               CyrusGray2012
# 427           LadariusGreen  SDG      WR  2012           LadariusGreen2012
# 428             VirgilGreen  DEN      TE  2012             VirgilGreen2012
# 429          LavelleHawkins  TEN      WR  2012          LavelleHawkins2012
# 430             LexHilliard  2TM      RB  2012             LexHilliard2012
# 433           ChrisPressley  CIN      RB  2012           ChrisPressley2012
# 434          MichaelPreston  TEN      WR  2012          MichaelPreston2012
# 435              DJWilliams  GNB      TE  2012              DJWilliams2012
# 436           SeyiAjirotutu  SDG      WR  2012           SeyiAjirotutu2012
# 437            BrandonBanks  WAS      WR  2012            BrandonBanks2012
# 438            GarrettCelek  SFO      TE  2012            GarrettCelek2012
# 439              JoshCribbs  CLE      WR  2012              JoshCribbs2012
# 440                 RoyHelu  WAS      RB  2012                 RoyHelu2012
# 441            QuinnJohnson  TEN      RB  2012            QuinnJohnson2012
# 442             SteveManeri  KAN      TE  2012             SteveManeri2012
# 443          RandyMcMichael  SDG      TE  2012          RandyMcMichael2012
# 444            DavidPaulson  PIT      TE  2012            DavidPaulson2012
# 445              IsaiahPead  STL      RB  2012              IsaiahPead2012
# 446               AlexSmith  CLE      TE  2012               AlexSmith2012
# 447          TaylorThompson  TEN      TE  2012          TaylorThompson2012
# 448              RyanWhalen  CIN      WR  2012              RyanWhalen2012
# 449              DevonWylie  KAN      WR  2012              DevonWylie2012
# 450               KyleAdams  CHI      TE  2012               KyleAdams2012
# 451           ArreliousBenn  TAM      WR  2012           ArreliousBenn2012
# 452           GregCamarillo  NOR      WR  2012           GregCamarillo2012
# 453             JohnCarlson  MIN      TE  2012             JohnCarlson2012
# 454            ToneyClemons  JAX      WR  2012            ToneyClemons2012
# 455              NateEachus  KAN      RB  2012              NateEachus2012
# 456            JeromeFelton  MIN      RB  2012            JeromeFelton2012
# 457            CharlyMartin  SEA      WR  2012            CharlyMartin2012
# 458            RuvellMartin  BUF      WR  2012            RuvellMartin2012
# 459            BernardScott  CIN      RB  2012            BernardScott2012
# 460          AnthonySherman  ARI      RB  2012          AnthonySherman2012
# 461               KrisAdams  IND      WR  2012               KrisAdams2012
# 462           JarrettBoykin  GNB      WR  2012           JarrettBoykin2012
# 464           TravarisCadet  NOR      RB  2012           TravarisCadet2012
# 465           AndreCaldwell  DEN      WR  2012           AndreCaldwell2012
# 466             BenHartsock  CAR      TE  2012             BenHartsock2012
# 467          JerrelJernigan  NYG      WR  2012          JerrelJernigan2012
# 468             TaiwanJones  OAK      RB  2012             TaiwanJones2012
# 469          JermaineKearse  SEA      WR  2012          JermaineKearse2012
# 470             MattLeinart  OAK      QB  2012             MattLeinart2012
# 471             MikeMcNeill  STL      TE  2012             MikeMcNeill2012
# 472             DavidNelson  BUF      TE  2012             DavidNelson2012
# 473             JavonRinger  TEN      RB  2012             JavonRinger2012
# 474          DeonteThompson  BAL      WR  2012          DeonteThompson2012
# 475               EricWeems  CHI      WR  2012               EricWeems2012
# 476             JohnnyWhite  2TM      RB  2012             JohnnyWhite2012
# 477                 TJYates  HOU      QB  2012                 TJYates2012
# 478           DerekAnderson  CAR      QB  2012           DerekAnderson2012
# 479           DezmonBriscoe  WAS      WR  2012           DezmonBriscoe2012
# 480             ChaseDaniel  NOR      QB  2012             ChaseDaniel2012
# 481                 JimDray  ARI      TE  2012                 JimDray2012
# 482               MattFlynn  SEA      QB  2012               MattFlynn2012
# 483            MardyGilyard  2TM      WR  2012            MardyGilyard2012
# 484         BruceGradkowski  CIN      QB  2012         BruceGradkowski2012
# 485              CoryHarkey  STL      RB  2012              CoryHarkey2012
# 486            KreggLumpkin  NYG      RB  2012            KreggLumpkin2012
# 487            CollinMooney  TEN      RB  2012            CollinMooney2012
# 488            JakeOConnell  KAN      TE  2012            JakeOConnell2012
# 489             DanOrlovsky  TAM      QB  2012             DanOrlovsky2012
# 490              ChrisOwusu  TAM      WR  2012              ChrisOwusu2012
# 491           EvanRodriguez  CHI      TE  2012           EvanRodriguez2012
# 492          WeslyeSaunders  IND      TE  2012          WeslyeSaunders2012
# 493            AlfonsoSmith  ARI      RB  2012            AlfonsoSmith2012
# 495             HaydenSmith  NYJ      TE  2012             HaydenSmith2012
# 496        AnthonyArmstrong  2TM      WR  2012        AnthonyArmstrong2012
# 497              MattAsiata  MIN      RB  2012              MattAsiata2012
# 498               LaRonByrd  ARI      WR  2012               LaRonByrd2012
# 499             ShaunChapas  DET      RB  2012             ShaunChapas2012
# 500            ChaseCoffman  ATL      TE  2012            ChaseCoffman2012
# 501            AustinCollie  IND      WR  2012            AustinCollie2012
# 502             ChrisCooley  WAS      TE  2012             ChrisCooley2012
# 503            TrentEdwards  PHI      QB  2012            TrentEdwards2012
# 504           TommyGallarda  ATL      TE  2012           TommyGallarda2012
# 505           DavidGilreath  PIT      WR  2012           DavidGilreath2012
# 506          JonathanGrimes  3TM      RB  2012          JonathanGrimes2012
# 507         ChrisGronkowski  DEN      RB  2012         ChrisGronkowski2012
# 508               DanHerron  CIN      RB  2012               DanHerron2012
# 509             AndreHolmes  DAL      WR  2012             AndreHolmes2012
# 510            RobertHughes  IND      RB  2012            RobertHughes2012
# 511           BrandonJacobs  SFO      RB  2012           BrandonJacobs2012
# 512          DominiqueJones  IND      RB  2012          DominiqueJones2012
# 513             StefanLogan  DET      RB  2012             StefanLogan2012
# 514             ReaganMauia  ARI      RB  2012             ReaganMauia2012
# 515           CoreyMcIntyre  BUF      RB  2012           CoreyMcIntyre2012
# 516               EvanMoore  2TM      TE  2012               EvanMoore2012
# 517           PrestonParker  TAM      WR  2012           PrestonParker2012
# 518           LousakaPolite  ATL      RB  2012           LousakaPolite2012
# 519              ZachPotter  JAX      TE  2012              ZachPotter2012
# 520            AllenReisner  2TM      TE  2012            AllenReisner2012
# 521            CourtneyRoby  NOR      WR  2012            CourtneyRoby2012
# 522        DaneSanzenbacher  2TM      WR  2012        DaneSanzenbacher2012
# 523              DaRelScott  NYG      RB  2012              DaRelScott2012
# 524              RustySmith  TEN      QB  2012              RustySmith2012
# 526          IsaiahStanback  JAX      WR  2012          IsaiahStanback2012
# 527        SammieStroughter  TAM      WR  2012        SammieStroughter2012
# 528             WillTaufoou  JAX      RB  2012             WillTaufoou2012
# 529              RyanTaylor  GNB      TE  2012              RyanTaylor2012
# 530            TylerThigpen  BUF      QB  2012            TylerThigpen2012
# 531            JordanTodman  JAX      RB  2012            JordanTodman2012
# 532             JordanWhite  NYJ      WR  2012             JordanWhite2012
# 533         KeilandWilliams  2TM      RB  2012         KeilandWilliams2012
# 534           KellenWinslow  NWE      TE  2012           KellenWinslow2012
# 545               DavidCarr  NYG      QB  2012               DavidCarr2012
# 546           KellenClemens  STL      QB  2012           KellenClemens2012
# 551                 MikeCox  ATL      RB  2012                 MikeCox2012
# 564          MichaelHiggins  NOR      TE  2012          MichaelHiggins2012
# 572              LukeMcCown  ATL      QB  2012              LukeMcCown2012
# 575            LegeduNaanee  MIA      WR  2012            LegeduNaanee2012
# 579            NathanPalmer  IND      WR  2012            NathanPalmer2012
# 585             OwenSchmitt  OAK      RB  2012             OwenSchmitt2012
# 589             BradSmelley  CLE      TE  2012             BradSmelley2012
# 591             ArmondSmith  CAR      RB  2012             ArmondSmith2012
# 601                 JoeWebb  MIN      QB  2012                 JoeWebb2012
# 606             DedrickEpps  NYJ      TE  2012             DedrickEpps2012
# 607               TedGinnJr  SFO      WR  2012               TedGinnJr2012
# 608           BrockOsweiler  DEN      QB  2012           BrockOsweiler2012
# 609           GrahamHarrell  GNB      QB  2012           GrahamHarrell2012
# 611             RyanMallett  NWE      QB  2012             RyanMallett2012
# 612                JoeAdams  CAR      WR  2012                JoeAdams2012
# 0             JamaalCharles  KAN      RB  2013           JamaalCharles2013
# 1               LeSeanMcCoy  PHI      RB  2013             LeSeanMcCoy2013
# 2             PeytonManning  DEN      QB  2013           PeytonManning2013
# 3                 MattForte  CHI      RB  2013               MattForte2013
# 4               JimmyGraham  NOR      TE  2013             JimmyGraham2013
# 5             MarshawnLynch  SEA      RB  2013           MarshawnLynch2013
# 6            KnowshonMoreno  DEN      RB  2013          KnowshonMoreno2013
# 7                JoshGordon  CLE      WR  2013              JoshGordon2013
# 8           DemaryiusThomas  DEN      WR  2013         DemaryiusThomas2013
# 9             CalvinJohnson  DET      WR  2013           CalvinJohnson2013
# 10                DrewBrees  NOR      QB  2013               DrewBrees2013
# 11                  AJGreen  CIN      WR  2013                 AJGreen2013
# 12          BrandonMarshall  CHI      WR  2013         BrandonMarshall2013
# 13             AntonioBrown  PIT      WR  2013            AntonioBrown2013
# 14                EddieLacy  GNB      RB  2013               EddieLacy2013
# 15                DezBryant  DAL      WR  2013               DezBryant2013
# 16            DeMarcoMurray  DAL      RB  2013           DeMarcoMurray2013
# 17           AdrianPeterson  MIN      RB  2013          AdrianPeterson2013
# 18            AlshonJeffery  CHI      WR  2013           AlshonJeffery2013
# 19               EricDecker  DEN      WR  2013              EricDecker2013
# 20             ChrisJohnson  TEN      RB  2013            ChrisJohnson2013
# 21              VernonDavis  SFO      TE  2013             VernonDavis2013
# 22            DeSeanJackson  PHI      WR  2013           DeSeanJackson2013
# 23              FredJackson  BUF      RB  2013             FredJackson2013
# 24              JordyNelson  GNB      WR  2013             JordyNelson2013
# 25               ReggieBush  DET      RB  2013              ReggieBush2013
# 26              RyanMathews  SDG      RB  2013             RyanMathews2013
# 27             JuliusThomas  DEN      TE  2013            JuliusThomas2013
# 28             AndreJohnson  HOU      WR  2013            AndreJohnson2013
# 30                FrankGore  SFO      RB  2013               FrankGore2013
# 31               LeVeonBell  PIT      RB  2013              LeVeonBell2013
# 32             PierreGarcon  WAS      WR  2013            PierreGarcon2013
# 33           VincentJackson  TAM      WR  2013          VincentJackson2013
# 34             AlfredMorris  WAS      RB  2013            AlfredMorris2013
# 35             TonyGonzalez  ATL      TE  2013            TonyGonzalez2013
# 36             AnquanBoldin  SFO      WR  2013            AnquanBoldin2013
# 37           GiovaniBernard  CIN      RB  2013          GiovaniBernard2013
# 38            JordanCameron  CLE      TE  2013           JordanCameron2013
# 39              JasonWitten  DAL      TE  2013             JasonWitten2013
# 40                CamNewton  CAR      QB  2013               CamNewton2013
# 41               JoiqueBell  DET      RB  2013              JoiqueBell2013
# 42          LarryFitzgerald  ARI      WR  2013         LarryFitzgerald2013
# 43               AndrewLuck  IND      QB  2013              AndrewLuck2013
# 44                 ZacStacy  STL      RB  2013                ZacStacy2013
# 45               AndyDalton  CIN      QB  2013              AndyDalton2013
# 46              KeenanAllen  SDG      WR  2013             KeenanAllen2013
# 47             PhilipRivers  SDG      QB  2013            PhilipRivers2013
# 48            JulianEdelman  NWE      WR  2013           JulianEdelman2013
# 49              CharlesClay  MIA      TE  2013             CharlesClay2013
# 50                GregOlsen  CAR      TE  2013               GregOlsen2013
# 51            DannyWoodhead  SDG      RB  2013           DannyWoodhead2013
# 52          MatthewStafford  DET      QB  2013         MatthewStafford2013
# 53                 TYHilton  IND      WR  2013                TYHilton2013
# 54              TorreySmith  BAL      WR  2013             TorreySmith2013
# 55              MarvinJones  CIN      WR  2013             MarvinJones2013
# 56         MauriceJonesDrew  JAX      RB  2013        MauriceJonesDrew2013
# 57              RileyCooper  PHI      WR  2013             RileyCooper2013
# 58                WesWelker  DEN      WR  2013               WesWelker2013
# 59             MichaelFloyd  ARI      WR  2013            MichaelFloyd2013
# 61             AntonioGates  SDG      TE  2013            AntonioGates2013
# 62           RashadJennings  OAK      RB  2013          RashadJennings2013
# 63            RussellWilson  SEA      QB  2013           RussellWilson2013
# 64         DeAngeloWilliams  CAR      RB  2013        DeAngeloWilliams2013
# 65         MartellusBennett  CHI      TE  2013        MartellusBennett2013
# 66             PierreThomas  NOR      RB  2013            PierreThomas2013
# 67              MikeWallace  MIA      WR  2013             MikeWallace2013
# 68            BrianHartline  MIA      WR  2013           BrianHartline2013
# 69          ColinKaepernick  SFO      QB  2013         ColinKaepernick2013
# 70           MarquesColston  NOR      WR  2013          MarquesColston2013
# 71               GoldenTate  SEA      WR  2013              GoldenTate2013
# 72                 TonyRomo  DAL      QB  2013                TonyRomo2013
# 73                JaredCook  STL      TE  2013               JaredCook2013
# 74               VictorCruz  NYG      WR  2013              VictorCruz2013
# 75                NickFoles  PHI      QB  2013               NickFoles2013
# 76            DelanieWalker  TEN      TE  2013           DelanieWalker2013
# 78           AndreEllington  ARI      RB  2013          AndreEllington2013
# 79            KendallWright  TEN      WR  2013           KendallWright2013
# 80        BenRoethlisberger  PIT      QB  2013       BenRoethlisberger2013
# 81                AlexSmith  KAN      QB  2013               AlexSmith2013
# 82                 TomBrady  NWE      QB  2013                TomBrady2013
# 83                 MattRyan  ATL      QB  2013                MattRyan2013
# ...
# 112  SFO2020
# 113  ARI2020
# 114  CIN2020
# 115  DAL2020
# 116  LAR2020
# 117  NYJ2020
# 118  NOR2020
# 119  DET2020
# 120  CIN2020
# 121  LAC2020
# 123  WAS2020
# 124  DEN2020
# 125  ATL2020
# 126  IND2020
# 127  PHI2020
# 128  DEN2020
# 129  BUF2020
# 130  LAC2020
# 131  CHI2020
# 132  NOR2020
# 133  GNB2020
# 134  MIA2020
# 135  BUF2020
# 136  JAX2020
# 137  JAX2020
# 138  JAX2020
# 139  ARI2020
# 140  NYG2020
# 141  TAM2020
# 142  GNB2020
# 143  ATL2020
# 144  SFO2020
# 145  IND2020
# 146  DAL2020
# 147  LAR2020
# 148  CHI2020
# 149  NYG2020
# 150  NOR2020
# 151  BUF2020
# 152  DEN2020
# 154  KAN2020
# 155  LAR2020
# 156  PIT2020
# 157  NWE2020
# 158  LAC2020
# 159  NYJ2020
# 160  LAR2020
# 161  CLE2020
# 162  NWE2020
# 163  SEA2020
# 164  SFO2020
# 165  DAL2020
# 522  DAL2021
# 523  IND2021
# 524  NOR2021
# 526  PIT2021
# 527  DEN2021
# 528  DET2021
# 529  NYJ2021
# 530  JAX2021
# 531  CAR2021
# 532  NOR2021
# 533  MIA2021
# 534  HOU2021
# 535  TEN2021
# 536  TAM2021
# 537  2TM2021
# 538  KAN2021
# 539  CAR2021
# 540  MIA2021
# 541  SFO2021
# 542  CHI2021
# 543  HOU2021
# 544  NOR2021
# 545  LVR2021
# 546  HOU2021
# 547  NYG2021
# 548  PHI2021
# 549  ARI2021
# 550  BAL2021
# 551  PIT2021
# 552  CIN2021
# 553  LAR2021
# 554  NYJ2021
# 555  DET2021
# 557  BAL2021
# 558  NYG2021
# 559  LVR2021
# 560  IND2021
# 561  DEN2021
# 562  ATL2021
# 563  IND2021
# 564  WAS2021
# 565  LAR2021
# 566  ATL2021
# 567  ARI2021
# 568  LAR2021
# 569  LAR2021
# 570  ARI2021
# 571  CLE2021
# 572  MIA2021
# 573  MIA2021
# 574  PIT2021
# 575  MIA2021
# 576  2TM2021
# 577  CIN2021
# 578  LAR2021
# 579  CHI2021
# 580  SFO2021
# 581  PIT2021
# 582  PHI2021
# 583  3TM2021
# 584  CAR2021
# 585  MIN2021
# 586  BAL2021
# 588  DET2021
# 589  NOR2021
# 590  NOR2021
# 597  NYG2021
# 599  TAM2021
# 601  SEA2021
# 602  GNB2021
# 604  BAL2021
# 613  JAX2021
# 616  LAC2021
# 617  ARI2021
# 625  LAC2021
# 634  LVR2021
# 648  BAL2021
# 651  MIN2021
# 655  2TM2021
# 656  LVR2021
# 659  DEN2021
# 676  BUF2021
# 681  TAM2021
# 682  TEN2021
# 683  IND2021
# 684  ATL2021
# 685  TEN2021
# 686  GNB2021
# 687  TEN2021
# 689  2TM2021
# 690  LAR2021
# 691  ATL2021
# 692  DEN2021

# %%
advPass

# %%
advPassGame

# %%
advRush

# %%
advRushGame

# %%
advRec

# %%
advRecGame

# %%
list1 = []
list2 = []

def addto(year,trigger=False):
    if trigger is False:
        list1.append(year)
    else:
        list2.append(year)

# %%
def create(startYear,endYear,function,PPG=False):
    flag = PPG
    years = []
    # Iterates through years specified
    for year in range(startYear, endYear + 1):
        years.append(year)
    function(years,flag)

# %%
create(2017,2019,addto,PPG=False)

# %%
print(list1)

# %%
print(list2)

# %%
advRush

# %%
advRec

# %%
PassLen = len(advPass)
RushLen = len(advRush)
RecLen = len(advRec)
print(f'Current sizes of the DFs are: Passing - {PassLen}, Rushing - {RushLen}, Receiving - {RecLen}.')

# %%
teams

# %%
teams.dtypes

# %%
merged = advRush.merge(teams,how='outer',left_on=['TmID','Year'],right_on=['TmID','Year'])
merged

# %%
#merged = merged.drop(columns=['Tm_y','G_y','Abbr'])
merged = merged.rename(columns={"Tm_x": "Tm","G_x":"G"})
merged = merged.dropna(subset=['Player'])
merged

# %%
merged.dtypes

# %%
merged

# %%
#fantDB['Tm'].value_counts()

# %%
#fantDB[(fantDB['Tm'].isin(['4TM','3TM','2TM'])) & (fantDB['FPts'] >= 80)]
